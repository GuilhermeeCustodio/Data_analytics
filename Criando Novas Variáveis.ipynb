# %% [markdown]
# # Relatório de Analise VI

# %% [markdown]
# ## Criando Novas variáveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('Dados/aluguel_residencial.csv', sep = ';')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# ...

# %% [markdown]
# ## Transformando uma nova variável

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto
# 0       500.0  60.0       2260.0
# 1         NaN   NaN          NaN
# ...

# %%
dados['Valor m2'] = dados['Valor']/dados['Area']

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto   Valor m2
# 0       500.0  60.0       2260.0  42.500000
# ...

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2
# 0       500.0  60.0       2260.0     42.50
# ...

# %%
dados['Valor m2'] = (dados['Valor Bruto']/dados['Area']).round(2)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2
# 0      1700.0       500.0  60.0       2260.0     56.50
# ...

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2 Tipo Agregado
# ...

# %% [markdown]
# ## Excluindo variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor m2']])

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto  Valor m2
# 0   Apartamento     56.50       2260.0     56.50
# 1          Casa       NaN          NaN       NaN
# 2   Apartamento     80.67       1210.0     80.67
# 3   Apartamento       NaN          NaN       NaN
# 4   Apartamento       NaN          NaN       NaN
# 5   Apartamento     32.36       1618.0     32.36
# 6          Casa       NaN          NaN       NaN
# 7          Casa       NaN          NaN       NaN
# 8   Apartamento       NaN          NaN       NaN
# 9   Apartamento     31.66       2216.0     31.66

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado  Valor m2  Valor m2
# 0   Apartamento     56.50     56.50
# 1          Casa       NaN       NaN
# 2   Apartamento     80.67     80.67
# 3   Apartamento       NaN       NaN
# 4   Apartamento       NaN       NaN
# 5   Apartamento     32.36     32.36
# 6          Casa       NaN       NaN
# 7          Casa       NaN       NaN
# 8   Apartamento       NaN       NaN
# 9   Apartamento     31.66     31.66

# %%
dados_aux.pop('Valor m2')
# Out:
#        Valor m2  Valor m2
# 0         56.50     56.50
# 1           NaN       NaN
# 2         80.67     80.67
# 3           NaN       NaN
# 4           NaN       NaN
# ...         ...       ...
# 22575     20.54     20.54
# 22576     43.52     43.52
# 22577     33.85     33.85
# 22578     40.54     40.54
# 22579       NaN       NaN
#
# [22580 rows x 2 columns]

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado
# 0   Apartamento
# 1          Casa
# 2   Apartamento
# 3   Apartamento
# 4   Apartamento
# 5   Apartamento
# 6          Casa
# 7          Casa
# 8   Apartamento
# 9   Apartamento

# %% [markdown]
# ### axis(eixo) = 1 colunas
# ### axis(eixo) = 0 linhas

# %%
dados.drop(['Valor Bruto', 'Vagas'], axis = 1, inplace = True)

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1       0    40   1700.0
# 1                Casa  Jardim Botânico        2       1   100   7000.0
# 2         Apartamento           Centro        1       0    15    800.0
# 3         Apartamento     Higienópolis        1       0    48    800.0
# 4         Apartamento     Vista Alegre        3       0    70   1200.0
# 5         Apartamento         Cachambi        2       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2       0    65   1000.0
# 8         Apartamento           Centro        1       0    36   1200.0
# 9         Apartamento           Grajaú        2       0    70   1500.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       500.0  60.0     56.50   Apartamento
# 1         NaN   NaN       NaN          Casa
# 2       390.0  20.0     80.67   Apartamento
# ...

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep = ';', index = False)
